# %%
import os

# Get list of all .csv files in the current directory
csv_files = [f for f in os.listdir('.') if f.endswith('.csv')]

# Format the file paths and names
formatted_files = []
for i, file in enumerate(csv_files, start=1):
    formatted_files.append(f"file_{i:02} = r'..\\Data_Artifacts\\{file}'")

print(f'#copy and paste the below paths and file = file_xx so you can easily comment in/out the files:\n')
for formatted_file in formatted_files:
    print(formatted_file)

print()
for i in range(len(formatted_files)):
    if i == 0:
        print(f"file = file_{i+1:02}")
    else:
        print(f"# file = file_{i+1:02}")
# Out:
# #copy and paste the below paths and file = file_xx so you can easily comment in/out the files:
#
# file_01 = r'..\Data_Artifacts\cfb_ref_stats.csv'
# file_02 = r'..\Data_Artifacts\draft_history.csv'
# file_03 = r'..\Data_Artifacts\nfl_career_statistics.csv'
# file_04 = r'..\Data_Artifacts\nfl_draft_profiles_clean.csv'
# file_05 = r'..\Data_Artifacts\nfl_draft_prospects_clean.csv'
# file_06 = r'..\Data_Artifacts\otcap_career_earnings.csv'
# file_07 = r'..\Data_Artifacts\pro_ref_individ.csv'
# file_08 = r'..\Data_Artifacts\pro_ref_individ_raw.csv'
# file_09 = r'..\Data_Artifacts\pro_ref_stats.csv'
#
# file = file_01
# # file = file_02
# # file = file_03
# # file = file_04
# # file = file_05
# # file = file_06
# # file = file_07
# # file = file_08
# # file = file_09

# %%
#copy and paste the below paths and file = file_xx so you can easily comment in/out the files:


file_07 = r'..\Data_Artifacts\pro_ref_individ.csv'
# '(497) rows, (23) cols'
# ("['player', 'hof', 'all_star', 'SBs', 'wAV', 'AV', 'record', 'games', "
#  "'win_%', 'pass_yards', 'TD', 'comp_%', 'YPA', 'int', 'drafted', 'team', "
#  "'rd', 'pick', 'ht', 'wt', 'hand', 'wins', 'loss']")



file_03 = r'..\Data_Artifacts\nfl_career_statistics.csv'
    # r'..\Data_Artifacts\otcap_career_earnings.csv'
    # r'..\Data_Artifacts\pro_ref_stats.csv'

# (637) rows, (20) cols'
# ("['player', 'drafted', 'yrs_played', 'teams', 'hof', 'wAV', 'earnings_mils', "
#  "'comp_%', 'pass_rating', 'comp', 'att', 'pass_yds', 'TD', 'pass_yds_game', "
#  "'int', 'int_%', 'pick_6', 'sacks', '4QC', 'GWD']")


file_01 = r'..\Data_Artifacts\cfb_ref_stats.csv'
# ("['player', 'school', 'passer_eff_rate', 'yrs_played', 'from', 'to', 'comp', "
#  "'att', 'comp_%', 'pass_yds', 'pass_td', 'int', 'tot_plays', 'tot_yds', "
#  "'tot_td', 'pyds_att', 'adj_pyds_att', 'pass-yds-per-cmp', 'yds_pgame', "
#  "'yds_pplay']")

file_02 = r'..\Data_Artifacts\draft_history.csv'
# '(1078) rows, (8) cols'
# "['Year', 'No.', 'Round', 'Pick', 'Player', 'Name', 'Team', 'College']

file_03 = r'..\Data_Artifacts\nfl_career_statistics.csv'
# (637) rows, (20) cols'
# ("['player', 'drafted', 'yrs_played', 'teams', 'hof', 'wAV', 'earnings_mils', "
#  "'comp_%', 'pass_rating', 'comp', 'att', 'pass_yds', 'TD', 'pass_yds_game', "
#  "'int', 'int_%', 'pick_6', 'sacks', '4QC', 'GWD']")

file_04 = r'..\Data_Artifacts\nfl_draft_profiles_clean.csv'
# '(601) rows, (6) cols'
# "['player_id', 'player_name', 'weight', 'height', 'school', 'grade']"

file_05 = r'..\Data_Artifacts\nfl_draft_prospects_clean.csv'
# '(278) rows, (13) cols'
# ("['draft_year', 'player_id', 'player_name', 'school', 'pick', 'overall', "
#  "'round', 'traded', 'trade_note', 'team', 'weight', 'height', 'grade']")




# These files combined into cleaned file file_03
file_06 = r'..\Data_Artifacts\otcap_career_earnings.csv'
# '(391) rows, (6) cols'
# ("['Player', 'Year_Drafted', 'Year_Final', 'Career Earnings (millions)', "
#  "'Cap-Inflated Earnings (millions)', 'Earnings By Team Dict']")
file_08 = r'..\Data_Artifacts\pro_ref_stats.csv'
# '(356) rows, (19) cols'
# ("['player', 'pass_yds', 'comp', 'att', 'TD', 'pass_rating', 'int', 'sacks', "
#  "'pick_6', 'pass_yds_game', 'comp_%', 'int_%', 'GWD', '4QC', 'wAV', "
#  "'num_teams', 'teams', 'hof', 'yrs_played']")


# file = file_01
# file = file_02
file = file_03
# file = file_04
# file = file_05
# file = file_06
# file = file_07
# file = file_08

# %%
import csv
import pandas as pd
from pprint import pprint
df = pd.read_csv(file)

display(f'filename{file}')
row_num= len(df)
col_num= len(df.columns)

display(f'({row_num}) rows, ({col_num}) cols')
pprint(f'{df.columns.tolist()}')
display(df.iloc[:,:10].head())
display(df.iloc[:,:10].tail())
print('next 10: ----------------------------------------------')
display(df.iloc[:,10:20].head())
display(df.iloc[:,10:20].tail())

if col_num > 20:
    print('next 10: ----------------------------------------------')
    display(df.iloc[:,20:].head())
    display(df.iloc[:,20:].tail())

import_string = (f'''# To import this file in a separate ipynb notebook, copy and paste the following code block:

import pandas as pd      
rel_path = r'{file}'           
df = pd.read_csv(rel_path)

display(df.iloc[:, :10].head())
display(df.iloc[:, 10:].head())
display(df.columns)
''')
print(import_string)
# Out:
# 'filename..\\Data_Artifacts\\nfl_career_statistics.csv'
# '(637) rows, (20) cols'
# ("['player', 'drafted', 'yrs_played', 'teams', 'hof', 'wAV', 'earnings_mils', "
#  "'comp_%', 'pass_rating', 'comp', 'att', 'pass_yds', 'TD', 'pass_yds_game', "
#  "'int', 'int_%', 'pick_6', 'sacks', '4QC', 'GWD']")
#                player  drafted  yrs_played
# 0           Tom Brady   2000.0        23.0  \
# 1          Drew Brees   2001.0        20.0
# 2      Peyton Manning   1998.0        18.0
# 3         Brett Favre   1991.0        20.0
# 4  Ben Roethlisberger   2004.0        18.0
#
#                                        teams  hof    wAV  earnings_mils
# 0                 ['Patriots', 'Buccaneers']  0.0  184.0        317.620  \
# 1                     ['Saints', 'Chargers']  0.0  167.0        273.933
# 2                       ['Colts', 'Broncos']  1.0  176.0        247.714
# 3  ['Packers', 'Vikings', 'Jets', 'Falcons']  1.0  158.0        141.407
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
