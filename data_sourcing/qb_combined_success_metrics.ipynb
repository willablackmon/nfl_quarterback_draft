# %%
import pandas as pd

# want to merge Career statistics, earnings data, and Hall of Fame/Pro-Bowl data into one sheet
#   for use in analyzing a quarterback's success in the NFL and what metrics seem to be the most
#   important to determine success.

#Import CSVs

csv_path = "../Resources/qb_career_stats.csv"
stats_df = pd.read_csv(csv_path)

csv_path = "../Resources/qb_earnings.csv"
earnings_df = pd.read_csv(csv_path)

csv_path = "../Resources/qb_hof_career.csv"
hof_df = pd.read_csv(csv_path)

# %%
display(stats_df.head())
display(stats_df.info())
display(earnings_df.head())
display(earnings_df.info())
display(hof_df.head())
display(hof_df.info())
# Out:
#                Player    Yds_x      Years   Tm     Cmp      Att     TD  Rate
# 0           Tom Brady  89214.0  2000-2022  2TM  7753.0  12050.0  649.0  97.2  \
# 1          Drew Brees  80358.0  2001-2020  2TM  7142.0  10551.0  571.0  98.7
# 2     Peyton Manning+  71940.0  1998-2015  2TM  6125.0   9380.0  539.0  96.5
# 3        Brett Favre+  71838.0  1991-2010  4TM  6300.0  10169.0  508.0  86.0
# 4  Ben Roethlisberger  64088.0  2004-2021  pit  5440.0   8443.0  418.0  93.5
#
#      Int     Sk   Yds_y  Pick6    Y/G   Cmp%  Int%   4QC   GWD
# 0  212.0  565.0  3576.0   18.0  266.3  64.3%  1.8%  46.0  58.0
# 1  243.0  420.0  2991.0   27.0  280.0  67.7%  2.3%  36.0  53.0
# 2  251.0  303.0  1953.0   27.0  270.5  65.3%  2.7%  43.0  54.0
# 3  336.0  525.0  3487.0   32.0  237.9  62.0%  3.3%  28.0  43.0
# 4  211.0  554.0  3677.0   18.0  257.4  64.4%  2.5%  41.0  53.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 17 columns):
# ...

# %%
#Export csv
csv_path = "../Resources/.csv"
df_ .to_csv(csv_path, index=False)
